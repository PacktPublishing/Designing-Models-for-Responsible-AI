# %%
import art

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Flatten, InputLayer, Reshape

from art.estimators.classification import KerasClassifier

# if tf.executing_eagerly():
#     tf.python.framework.ops.disable_eager_execution()
tf.compat.v1.disable_eager_execution()

# %%
# Prepare the dataset and the model architecture.

import art
from art.utils import load_mnist

# Load the dataset, and split the test data into test and steal datasets.
(x_train, y_train), (x_test0, y_test0), _, _ = load_mnist()
len_steal = 5000
indices = np.random.permutation(len(x_test0))
x_steal = x_test0[indices[:len_steal]]
y_steal = y_test0[indices[:len_steal]]
x_test = x_test0[indices[len_steal:]]
y_test = y_test0[indices[len_steal:]]

im_shape = x_train[0].shape
def get_model(num_classes=10, c1=32, c2=64, d1=128):
    model = Sequential()
    model.add(Conv2D(c1, kernel_size=(3, 3), activation='relu', input_shape=im_shape))
    model.add(Conv2D(c2, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(d1, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=keras.losses.categorical_crossentropy, optimizer="sgd",
                          metrics=['accuracy'])
    return model

# %%
# Train the original model.
num_epochs = 5
model = get_model(num_classes=10, c1=32, c2=64, d1=128)
print("Original model training:")
model.fit(x_train, y_train, batch_size=100, epochs=num_epochs)
print("Original model evaluation:")
print(model.evaluate(x_test, y_test))
classifier_original = KerasClassifier(model, clip_values=(0, 1), use_logits=False)
# Out:
# Original model training:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 43s 720us/sample - loss: 0.6497 - accuracy: 0.8276
# Epoch 2/5
# 60000/60000 [==============================] - 43s 712us/sample - loss: 0.2417 - accuracy: 0.9278
# Epoch 3/5
# 60000/60000 [==============================] - 43s 722us/sample - loss: 0.1858 - accuracy: 0.9440
# Epoch 4/5
# 60000/60000 [==============================] - 44s 732us/sample - loss: 0.1533 - accuracy: 0.9539
# Epoch 5/5
# 60000/60000 [==============================] - 44s 731us/sample - loss: 0.1316 - accuracy: 0.9601
# Original model evaluation:
# /opt/anaconda3/lib/python3.8/site-packages/keras/engine/training_v1.py:2057: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# [0.11797760139107705, 0.9658]

# %%
# Stealing from the unprotected classifier.
from art.attacks import ExtractionAttack
from art.attacks.extraction import CopycatCNN, KnockoffNets

attack_catalogue = {"Probabilistic CopycatCNN": CopycatCNN(classifier=classifier_original,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=True),
                    "Argmax CopycatCNN": CopycatCNN(classifier=classifier_original,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=False),
                    "Probabilistic KnockoffNets": KnockoffNets(classifier=classifier_original,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=True),
                    "Argmax KnockoffNets": KnockoffNets(classifier=classifier_original,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=False),
                   }

results = []
for len_steal in [250, 500, 1000, 2000, 4000, 5000]:
    indices = np.random.permutation(len(x_test0))
    x_steal = x_test0[indices[:len_steal]]
    y_steal = y_test0[indices[:len_steal]]
    x_test = x_test0[indices[len_steal:]]
    y_test = y_test0[indices[len_steal:]]

    for name, attack in attack_catalogue.items():
        model_stolen = get_model(num_classes=10, c1=32, c2=64, d1=128)
        classifier_stolen = KerasClassifier(model_stolen, clip_values=(0, 1), use_logits=False)
        classifier_stolen = attack.extract(x_steal, y_steal, thieved_classifier=classifier_stolen)
        acc = classifier_stolen._model.evaluate(x_test, y_test)[1]
        print(name, ":", acc)
        results.append((name, len_steal, acc))
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/keras/engine/training_v1.py:2079: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# Train on 250 samples
# Epoch 1/5
# 250/250 [==============================] - 0s 959us/sample - loss: 2.3044 - accuracy: 0.0920
# Epoch 2/5
# 250/250 [==============================] - 0s 817us/sample - loss: 2.2843 - accuracy: 0.1120
# Epoch 3/5
# 250/250 [==============================] - 0s 822us/sample - loss: 2.2652 - accuracy: 0.1840
# Epoch 4/5
# 250/250 [==============================] - 0s 827us/sample - loss: 2.2480 - accuracy: 0.2920
# Epoch 5/5
# 250/250 [==============================] - 0s 820us/sample - loss: 2.2291 - accuracy: 0.3920
# Probabilistic CopycatCNN : 0.33046153
# Train on 250 samples
# Epoch 1/5
# 250/250 [==============================] - 0s 985us/sample - loss: 2.2951 - accuracy: 0.1160
# Epoch 2/5
# 250/250 [==============================] - 0s 833us/sample - loss: 2.2714 - accuracy: 0.1680
# Epoch 3/5
# 250/250 [==============================] - 0s 822us/sample - loss: 2.2479 - accuracy: 0.2600
# Epoch 4/5
# 250/250 [==============================] - 0s 825us/sample - loss: 2.2251 - accuracy: 0.3760
# Epoch 5/5
# 250/250 [==============================] - 0s 819us/sample - loss: 2.2014 - accuracy: 0.4200
# Argmax CopycatCNN : 0.36215386
# Probabilistic KnockoffNets : 0.21148717
# Argmax KnockoffNets : 0.35815385
# Train on 500 samples
# Epoch 1/5
# 500/500 [==============================] - 0s 877us/sample - loss: 2.2923 - accuracy: 0.1460
# Epoch 2/5
# 500/500 [==============================] - 0s 834us/sample - loss: 2.2711 - accuracy: 0.2460
# Epoch 3/5
# 500/500 [==============================] - 0s 840us/sample - loss: 2.2489 - accuracy: 0.3380
# Epoch 4/5
# 500/500 [==============================] - 0s 843us/sample - loss: 2.2243 - accuracy: 0.4500
# Epoch 5/5
# 500/500 [==============================] - 0s 840us/sample - loss: 2.1949 - accuracy: 0.5420
# Probabilistic CopycatCNN : 0.52705264
# Train on 500 samples
# Epoch 1/5
# 500/500 [==============================] - 0s 921us/sample - loss: 2.3025 - accuracy: 0.0920
# Epoch 2/5
# 500/500 [==============================] - 0s 811us/sample - loss: 2.2752 - accuracy: 0.1600
# Epoch 3/5
# 500/500 [==============================] - 0s 837us/sample - loss: 2.2471 - accuracy: 0.2100
# Epoch 4/5
# 500/500 [==============================] - 0s 826us/sample - loss: 2.2146 - accuracy: 0.3580
# Epoch 5/5
# 500/500 [==============================] - 0s 828us/sample - loss: 2.1744 - accuracy: 0.4500
# Argmax CopycatCNN : 0.46063158
# Probabilistic KnockoffNets : 0.44378948
# Argmax KnockoffNets : 0.47031578
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 1s 855us/sample - loss: 2.2730 - accuracy: 0.2700
# Epoch 2/5
# 1000/1000 [==============================] - 1s 813us/sample - loss: 2.2127 - accuracy: 0.5530
# Epoch 3/5
# 1000/1000 [==============================] - 1s 865us/sample - loss: 2.1201 - accuracy: 0.6290
# Epoch 4/5
# 1000/1000 [==============================] - 1s 809us/sample - loss: 1.9416 - accuracy: 0.6970
# Epoch 5/5
# 1000/1000 [==============================] - 1s 807us/sample - loss: 1.6149 - accuracy: 0.7320
# Probabilistic CopycatCNN : 0.746
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 1s 933us/sample - loss: 2.2781 - accuracy: 0.1820
# Epoch 2/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 2.2008 - accuracy: 0.4060
# Epoch 3/5
# 1000/1000 [==============================] - 1s 983us/sample - loss: 2.0789 - accuracy: 0.5530
# Epoch 4/5
# 1000/1000 [==============================] - 1s 991us/sample - loss: 1.8442 - accuracy: 0.6540
# Epoch 5/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.4163 - accuracy: 0.7170
# Argmax CopycatCNN : 0.7637778
# Probabilistic KnockoffNets : 0.78566664
# Argmax KnockoffNets : 0.67322224
# Train on 2000 samples
# Epoch 1/5
# 2000/2000 [==============================] - 2s 989us/sample - loss: 2.2598 - accuracy: 0.2170
# Epoch 2/5
# 2000/2000 [==============================] - 2s 853us/sample - loss: 2.0883 - accuracy: 0.5385
# Epoch 3/5
# 2000/2000 [==============================] - 2s 824us/sample - loss: 1.5586 - accuracy: 0.7365
# Epoch 4/5
# 2000/2000 [==============================] - 2s 825us/sample - loss: 0.8091 - accuracy: 0.8235
# Epoch 5/5
# 2000/2000 [==============================] - 2s 817us/sample - loss: 0.5155 - accuracy: 0.8695
# Probabilistic CopycatCNN : 0.861125
# Train on 2000 samples
# Epoch 1/5
# 2000/2000 [==============================] - 2s 834us/sample - loss: 2.2317 - accuracy: 0.3540
# Epoch 2/5
# 2000/2000 [==============================] - 2s 823us/sample - loss: 1.9490 - accuracy: 0.6365
# Epoch 3/5
# 2000/2000 [==============================] - 2s 844us/sample - loss: 1.1791 - accuracy: 0.7675
# Epoch 4/5
# 2000/2000 [==============================] - 2s 827us/sample - loss: 0.6141 - accuracy: 0.8390
# Epoch 5/5
# 2000/2000 [==============================] - 2s 813us/sample - loss: 0.4343 - accuracy: 0.8725
# Argmax CopycatCNN : 0.829
# Probabilistic KnockoffNets : 0.857375
# Argmax KnockoffNets : 0.789625
# Train on 4000 samples
# Epoch 1/5
# 4000/4000 [==============================] - 3s 844us/sample - loss: 2.2477 - accuracy: 0.1970
# Epoch 2/5
# 4000/4000 [==============================] - 4s 887us/sample - loss: 1.7650 - accuracy: 0.6532
# Epoch 3/5
# 4000/4000 [==============================] - 3s 809us/sample - loss: 0.6491 - accuracy: 0.8520
# Epoch 4/5
# 4000/4000 [==============================] - 3s 809us/sample - loss: 0.4116 - accuracy: 0.8982
# Epoch 5/5
# 4000/4000 [==============================] - 3s 808us/sample - loss: 0.3586 - accuracy: 0.9050
# Probabilistic CopycatCNN : 0.87733334
# Train on 4000 samples
# Epoch 1/5
# 4000/4000 [==============================] - 3s 813us/sample - loss: 2.1959 - accuracy: 0.4787
# Epoch 2/5
# 4000/4000 [==============================] - 3s 829us/sample - loss: 1.2631 - accuracy: 0.7715
# Epoch 3/5
# 4000/4000 [==============================] - 3s 811us/sample - loss: 0.4598 - accuracy: 0.8725
# Epoch 4/5
# 4000/4000 [==============================] - 3s 816us/sample - loss: 0.3326 - accuracy: 0.8992
# Epoch 5/5
# 4000/4000 [==============================] - 3s 821us/sample - loss: 0.2790 - accuracy: 0.9135
# Argmax CopycatCNN : 0.8746667
# Probabilistic KnockoffNets : 0.90183336
# Argmax KnockoffNets : 0.8753333
# Train on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 4s 857us/sample - loss: 1.9567 - accuracy: 0.5004
# Epoch 2/5
# 5000/5000 [==============================] - 4s 868us/sample - loss: 0.6713 - accuracy: 0.8404
# Epoch 3/5
# 5000/5000 [==============================] - 4s 838us/sample - loss: 0.4078 - accuracy: 0.8920
# Epoch 4/5
# 5000/5000 [==============================] - 4s 868us/sample - loss: 0.3665 - accuracy: 0.9110
# Epoch 5/5
# 5000/5000 [==============================] - 4s 828us/sample - loss: 0.3160 - accuracy: 0.9204
# Probabilistic CopycatCNN : 0.9026
# Train on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 4s 842us/sample - loss: 2.2106 - accuracy: 0.4198
# Epoch 2/5
# 5000/5000 [==============================] - 4s 829us/sample - loss: 1.1986 - accuracy: 0.7612
# Epoch 3/5
# 5000/5000 [==============================] - 4s 827us/sample - loss: 0.4265 - accuracy: 0.8754
# Epoch 4/5
# 5000/5000 [==============================] - 4s 835us/sample - loss: 0.3191 - accuracy: 0.9014
# Epoch 5/5
# 5000/5000 [==============================] - 4s 829us/sample - loss: 0.2713 - accuracy: 0.9144
# Argmax CopycatCNN : 0.8338
# Probabilistic KnockoffNets : 0.903
# Argmax KnockoffNets : 0.905

# %%
import pandas as pd
df = pd.DataFrame(results, columns=('Method Name', 'Stealing Dataset Size', 'Accuracy'))
fig, ax = plt.subplots(figsize=(8,6))
ax.set_xlabel("Stealing Dataset Size")
ax.set_ylabel("Stolen Model Accuracy")
for name, group in df.groupby("Method Name"):
    group.plot(1, 2, ax=ax, label=name)
plt.show()

# %%
# Prepare the defense layer.
from art.defences.postprocessor import ReverseSigmoid
postprocessor = ReverseSigmoid(beta=1.0, gamma=0.2)
classifier_protected = KerasClassifier(model, clip_values=(0, 1), use_logits=False, postprocessing_defences=postprocessor)

# Below is used by `FunctionallyEquivalentExtraction`.
model_flat = Sequential([InputLayer([784]), Reshape([28, 28, 1]), model])
model_flat.compile('sgd', 'categorical_crossentropy', ['accuracy'])
classifier_flat_protected = KerasClassifier(model_flat, clip_values=(0, 1), use_logits=False, postprocessing_defences=postprocessor)

# %%
# Stealing from the protected classifier.

attack_catalogue = {
                    "Probabilistic CopycatCNN (vs. Protected)": CopycatCNN(classifier=classifier_protected,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=True),
                    "Argmax CopycatCNN (vs. Protected)": CopycatCNN(classifier=classifier_protected,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=False),
                    "Probabilistic KnockoffNets (vs. Protected)": KnockoffNets(classifier=classifier_protected,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=True),
                    "Argmax KnockoffNets (vs. Protected)": KnockoffNets(classifier=classifier_protected,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=False),
#                     "FunctionallyEquivalentExtraction": FunctionallyEquivalentExtraction(classifier=classifier_flat_protected,
#                                               num_neurons=128),  # This one takes too long time for this dataset/model.
                    }

results_protected = []
for len_steal in [250, 500, 1000, 2000, 4000, 5000]:
    indices = np.random.permutation(len(x_test0))
    x_steal = x_test0[indices[:len_steal]]
    y_steal = y_test0[indices[:len_steal]]
    x_test = x_test0[indices[len_steal:]]
    y_test = y_test0[indices[len_steal:]]

    for name, attack in attack_catalogue.items():
        model_stolen = get_model(num_classes=10, c1=32, c2=64, d1=128)
        classifier_stolen = KerasClassifier(model_stolen, clip_values=(0, 1), use_logits=False)
        if name=="FunctionallyEquivalentExtraction":
            classifier_stolen = attack.extract(np.reshape(x_steal, [len(x_steal), -1]), y_steal, thieved_classifier=classifier_stolen)
        else:
            classifier_stolen = attack.extract(x_steal, y_steal, thieved_classifier=classifier_stolen)
        
        acc = classifier_stolen._model.evaluate(x_test, y_test)[1]
        print(name, ":", acc)
        results_protected.append((name, len_steal, acc))
# Out:
# Train on 250 samples
# Epoch 1/5
# 250/250 [==============================] - 0s 1ms/sample - loss: 2.3049 - accuracy: 0.1200
# Epoch 2/5
# 250/250 [==============================] - 0s 917us/sample - loss: 2.3044 - accuracy: 0.1160
# Epoch 3/5
# 250/250 [==============================] - 0s 980us/sample - loss: 2.3040 - accuracy: 0.1160
# Epoch 4/5
# 250/250 [==============================] - 0s 1ms/sample - loss: 2.3037 - accuracy: 0.1200
# Epoch 5/5
# 250/250 [==============================] - 0s 1ms/sample - loss: 2.3034 - accuracy: 0.1200
# /opt/anaconda3/lib/python3.8/site-packages/keras/engine/training_v1.py:2057: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# Probabilistic CopycatCNN (vs. Protected) : 0.10748718
# Train on 250 samples
# Epoch 1/5
# 250/250 [==============================] - 0s 1ms/sample - loss: 2.3044 - accuracy: 0.1000
# Epoch 2/5
# 250/250 [==============================] - 0s 830us/sample - loss: 2.2903 - accuracy: 0.1400
# Epoch 3/5
# 250/250 [==============================] - 0s 831us/sample - loss: 2.2761 - accuracy: 0.1640
# Epoch 4/5
# 250/250 [==============================] - 0s 872us/sample - loss: 2.2620 - accuracy: 0.1760
# Epoch 5/5
# 250/250 [==============================] - 0s 828us/sample - loss: 2.2480 - accuracy: 0.1920
# Argmax CopycatCNN (vs. Protected) : 0.18851282
# Probabilistic KnockoffNets (vs. Protected) : 0.11271795
# Argmax KnockoffNets (vs. Protected) : 0.41784614
# Train on 500 samples
# Epoch 1/5
# 500/500 [==============================] - 1s 1ms/sample - loss: 2.3034 - accuracy: 0.1460
# Epoch 2/5
# 500/500 [==============================] - 0s 812us/sample - loss: 2.3031 - accuracy: 0.1520
# Epoch 3/5
# 500/500 [==============================] - 0s 778us/sample - loss: 2.3028 - accuracy: 0.1520
# Epoch 4/5
# 500/500 [==============================] - 0s 897us/sample - loss: 2.3026 - accuracy: 0.1580
# Epoch 5/5
# 500/500 [==============================] - 0s 827us/sample - loss: 2.3024 - accuracy: 0.1460
# Probabilistic CopycatCNN (vs. Protected) : 0.16305263
# Train on 500 samples
# Epoch 1/5
# 500/500 [==============================] - 1s 1ms/sample - loss: 2.2891 - accuracy: 0.1420
# Epoch 2/5
# 500/500 [==============================] - 0s 979us/sample - loss: 2.2602 - accuracy: 0.3420
# Epoch 3/5
# 500/500 [==============================] - 0s 807us/sample - loss: 2.2310 - accuracy: 0.4760
# Epoch 4/5
# 500/500 [==============================] - 0s 781us/sample - loss: 2.1954 - accuracy: 0.5140
# Epoch 5/5
# 500/500 [==============================] - 0s 869us/sample - loss: 2.1507 - accuracy: 0.5720
# Argmax CopycatCNN (vs. Protected) : 0.51757896
# Probabilistic KnockoffNets (vs. Protected) : 0.14621052
# Argmax KnockoffNets (vs. Protected) : 0.27389473
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 2.3038 - accuracy: 0.1390
# Epoch 2/5
# 1000/1000 [==============================] - 1s 874us/sample - loss: 2.3024 - accuracy: 0.1950
# Epoch 3/5
# 1000/1000 [==============================] - 1s 892us/sample - loss: 2.3016 - accuracy: 0.1980
# Epoch 4/5
# 1000/1000 [==============================] - 1s 977us/sample - loss: 2.3011 - accuracy: 0.1960
# Epoch 5/5
# 1000/1000 [==============================] - 1s 973us/sample - loss: 2.3007 - accuracy: 0.1900
# Probabilistic CopycatCNN (vs. Protected) : 0.17511111
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 2.2842 - accuracy: 0.1940
# Epoch 2/5
# 1000/1000 [==============================] - 1s 906us/sample - loss: 2.2388 - accuracy: 0.4280
# Epoch 3/5
# 1000/1000 [==============================] - 1s 899us/sample - loss: 2.1727 - accuracy: 0.5340
# Epoch 4/5
# 1000/1000 [==============================] - 1s 880us/sample - loss: 2.0553 - accuracy: 0.6180
# Epoch 5/5
# 1000/1000 [==============================] - 1s 851us/sample - loss: 1.8293 - accuracy: 0.6980
# Argmax CopycatCNN (vs. Protected) : 0.7366667
# Probabilistic KnockoffNets (vs. Protected) : 0.08533333
# Argmax KnockoffNets (vs. Protected) : 0.7137778
# Train on 2000 samples
# Epoch 1/5
# 2000/2000 [==============================] - 2s 1ms/sample - loss: 2.3042 - accuracy: 0.1020
# Epoch 2/5
# 2000/2000 [==============================] - 2s 1ms/sample - loss: 2.3029 - accuracy: 0.1130
# Epoch 3/5
# 2000/2000 [==============================] - 2s 1ms/sample - loss: 2.3021 - accuracy: 0.1305
# Epoch 4/5
# 2000/2000 [==============================] - 2s 1ms/sample - loss: 2.3016 - accuracy: 0.1450
# Epoch 5/5
# 2000/2000 [==============================] - 2s 1ms/sample - loss: 2.3011 - accuracy: 0.1495
# Probabilistic CopycatCNN (vs. Protected) : 0.14525
# Train on 2000 samples
# Epoch 1/5
# 2000/2000 [==============================] - 2s 1ms/sample - loss: 2.2564 - accuracy: 0.2790
# Epoch 2/5
# 2000/2000 [==============================] - 2s 1ms/sample - loss: 2.0574 - accuracy: 0.6135
# Epoch 3/5
# 2000/2000 [==============================] - 2s 1ms/sample - loss: 1.4438 - accuracy: 0.7195
# Epoch 4/5
# 2000/2000 [==============================] - 2s 1ms/sample - loss: 0.7632 - accuracy: 0.8080
# Epoch 5/5
# 2000/2000 [==============================] - 2s 1ms/sample - loss: 0.5198 - accuracy: 0.8525
# Argmax CopycatCNN (vs. Protected) : 0.7955
# Probabilistic KnockoffNets (vs. Protected) : 0.208875
# Argmax KnockoffNets (vs. Protected) : 0.830625
# Train on 4000 samples
# Epoch 1/5
# 4000/4000 [==============================] - 4s 1ms/sample - loss: 2.3019 - accuracy: 0.0665
# Epoch 2/5
# 4000/4000 [==============================] - 4s 897us/sample - loss: 2.3010 - accuracy: 0.1215
# Epoch 3/5
# 4000/4000 [==============================] - 4s 934us/sample - loss: 2.3006 - accuracy: 0.1670
# Epoch 4/5
# 4000/4000 [==============================] - 4s 956us/sample - loss: 2.3002 - accuracy: 0.1873
# Epoch 5/5
# 4000/4000 [==============================] - 4s 998us/sample - loss: 2.2999 - accuracy: 0.1940
# Probabilistic CopycatCNN (vs. Protected) : 0.21783334
# Train on 4000 samples
# Epoch 1/5
# 4000/4000 [==============================] - 4s 922us/sample - loss: 2.1129 - accuracy: 0.3473
# Epoch 2/5
# 4000/4000 [==============================] - 3s 862us/sample - loss: 0.9812 - accuracy: 0.7835
# Epoch 3/5
# 4000/4000 [==============================] - 3s 869us/sample - loss: 0.4547 - accuracy: 0.8658
# Epoch 4/5
# 4000/4000 [==============================] - 4s 924us/sample - loss: 0.3506 - accuracy: 0.8913
# Epoch 5/5
# 4000/4000 [==============================] - 4s 933us/sample - loss: 0.3085 - accuracy: 0.9078
# Argmax CopycatCNN (vs. Protected) : 0.88016665
# Probabilistic KnockoffNets (vs. Protected) : 0.252
# Argmax KnockoffNets (vs. Protected) : 0.86433333
# Train on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 5s 1ms/sample - loss: 2.3025 - accuracy: 0.1522
# Epoch 2/5
# 5000/5000 [==============================] - 5s 1ms/sample - loss: 2.3005 - accuracy: 0.1912
# Epoch 3/5
# 5000/5000 [==============================] - 5s 1ms/sample - loss: 2.2997 - accuracy: 0.2088
# Epoch 4/5
# 5000/5000 [==============================] - 5s 1ms/sample - loss: 2.2990 - accuracy: 0.2384
# Epoch 5/5
# 5000/5000 [==============================] - 5s 965us/sample - loss: 2.2985 - accuracy: 0.2574
# Probabilistic CopycatCNN (vs. Protected) : 0.2558
# Train on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 5s 936us/sample - loss: 2.1362 - accuracy: 0.4630
# Epoch 2/5
# 5000/5000 [==============================] - 4s 883us/sample - loss: 0.9306 - accuracy: 0.7914
# Epoch 3/5
# 5000/5000 [==============================] - 4s 879us/sample - loss: 0.4156 - accuracy: 0.8802
# Epoch 4/5
# 5000/5000 [==============================] - 5s 904us/sample - loss: 0.3262 - accuracy: 0.9058
# Epoch 5/5
# 5000/5000 [==============================] - 4s 899us/sample - loss: 0.3028 - accuracy: 0.9094
# Argmax CopycatCNN (vs. Protected) : 0.7986
# Probabilistic KnockoffNets (vs. Protected) : 0.1868
# Argmax KnockoffNets (vs. Protected) : 0.9032

# %%
import pandas as pd
df_protected = pd.DataFrame(results_protected, columns=('Method Name', 'Stealing Dataset Size', 'Accuracy'))
fig, ax = plt.subplots(figsize=(8,6))
ax.set_xlabel("Stealing Dataset Size")
ax.set_ylabel("Stolen Model Accuracy")
for name, group in df_protected.groupby("Method Name"):
    group.plot(1, 2, ax=ax, label=name)
plt.show()

# %%
df_combined = pd.concat([df, df_protected])
groupby = df_combined.groupby("Method Name")

# %%
names = ["CopycatCNN", "KnockoffNets"]
for name in names:
    fig, ax = plt.subplots(figsize=(8,6))
    groupby.get_group("Probabilistic " + name).plot(1,2,ax=ax, label="Probabilistic " + name)
    groupby.get_group("Probabilistic " + name + " (vs. Protected)").plot(1,2,ax=ax, label="Probabilistic " + name + " (vs. Protected)")
    ax.set_xlabel("Stealing Dataset Size")
    ax.set_ylabel("Stolen Model Accuracy")
    fig.show()
# Out:
# <ipython-input-15-1207b4895878>:8: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-15-1207b4895878>:8: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Next Step: Using data augmentation can make the model stealing process much easier and faster, and can make the probabilistic attack much better.
